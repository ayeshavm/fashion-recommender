# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_dir = 'drive/MyDrive/2025/graph-fashion-recsys/data/images/zara'
output_dir = 'drive/MyDrive/2025/graph-fashion-recsys/data/output'

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
from PIL import Image
from pathlib import Path
import os

st.title("🧵 Fashion Recommender")

# 1. Recommendation Mode Toggle
mode = st.radio(
    "Choose recommendation mode:",
    ["Cosine Similarity", "Euclidean Distance", "Fusion Score"],
    index=0
)

# 2. Anchor Image Selection
anchor = st.selectbox("Pick an anchor item:", list(cosine_recs.keys()))

# 3. Load and show anchor image
st.image(str(Path("path/to/images") / anchor), caption="Anchor Item", width=200)

# 4. Get recommendations
if mode == "Cosine Similarity":
    recs = cosine_recs[anchor]
elif mode == "Euclidean Distance":
    recs = euclidean_recs[anchor]
else:
    recs = fusion_recs[anchor]

# 5. Show recommendations
st.write(f"Top {len(recs)} recommendations:")

for img_name, score in recs:
    col1, col2 = st.columns([1, 3])
    with col1:
        st.image(str(Path("path/to/images") / img_name), width=120)
    with col2:
        st.markdown(f"**{img_name}**  \nScore: `{score:.4f}`")
